# %%
import hyp_testing as hp
hp.hyp_test_fn()
# Out:
# Hypothesis Testing function inputs
# -----------------------------------------
# Enter the sample size: 16
#
# Is the population highly skewed? Enter 'y' for Yes and 'n' for No: n
#
# Does the population contain outliers? Enter 'y' for Yes and 'n' for No: n
#
# Enter the population mean: 56
#
# Enter the sample mean: 56.3
#
# Enter the sample standard deviation: 2.3
#
# Is this a one-tailed or two-tailed test? Enter 1 or 2: 2
# sample size: 16, dof: 15
# sample mean: 56.3
#
# Hypothesis Test results
# -------------------------------------
# type of hypothesis test: Two-tailed test for Population Mean
# distribution considered: t-distribution
# significance level, alpha: 0.05
# critical value, tα/2: 2.1314
# t stats: 0.522
#
# null hypothesis: μ = 56.0
# alternate hypothesis: μ != 56.0
#
# ***This image is purely for representation purpose only. Not to scale.***
# 'since t-stats is in the acceptance region, we can accept null hypothesis.'
